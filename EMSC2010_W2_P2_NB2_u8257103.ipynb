# %% [markdown]
# <a href="https://colab.research.google.com/github/cm06/EMSC2010-W2-P2/blob/main/EMSC2010_W2_P2_NB2_u8257103.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010_W2_P2_NB2
# ---
#
# *   Class: EMSC2010
# *   Week: 2
# *   Session: Practical 2
#
# ---
#
# From GitHub, you can open this notebook in Google Colab using the 'Open in Colab' button. Then:
#
# 1. Change the notebook name to include your U-number (e.g EMSC2010_W2_P2_NB2_uXXXXXXX.ipynb)
# 2. Save to Google Drive (*File* >>> *Save a copy in Drive*)
# 3. Click *Share* (top right of window)
# 4. Add the **Gmail** addresses of your group and send them a notification
#
# Your group should then open the notebook and:
#
# 5. Write the code for the Fermi estimation problem
#
# The group's edits will still be saved in your Google Drive. Once you can see the edits:
#
# 6. Commit to GitHub (*File* >>> *Save a copy in GitHub*)
# 7. Select the repository for your commit (same as your original repository)
# 8. Give a brief commit message (e.g. 'Commit including Bob's updates')
# 9. Check your GitHub repository, a copy of your notebook should be there.
#
# ---
#
# Because Google Drive is saving your work and the work of your collaborators automatically, you don't need to commit all minor edits to GitHub. Rather commit when you want to archive a version of your notebook because you have completed a substantial task.

# %% [markdown]
# # Group name: Charlotte's group
# # Fermi estimation problem: how many fishs are in the ocean
#
# ### This code was written by Oceans eleven variables

# %%
#What is the volume of the ocean? From week 1 estimation:
V_ocean = 906000000 #EP

# %%
#Fish amount per km^3 - coastal
Fish_C = 6000000000

# %%
#fish amount per km3 - open ocean

# %%
#fish amount per m3 - poles
#converting to m3 to km3

# %%
#Number of krill in the ocean
#At least 2

# %%
#Fish density at poles (per km^3)
Fish_P = 75 #75 fish per km^3

# %%
#Fish density in the deep ocean (per km^3)
Fish_D = 50 #50 fish per km^3

# %%
#Fish density in the open ocean (per km^3)
Fish_O = 200 #200 fish per km^3

# %%
#Percentage of ocean coastal
Coastal = 0.01
print(Coastal)
# Out:
# 0.01

# %%
#Percentage of ocean open
Open = 94*2/300
print(Open)
# Out:
# 0.6266666666666667

# %%
#Percentage of ocean deep
Deep = 94*1/300
print(Deep)
# Out:
# 0.31333333333333335

# %%
#Percentage of ocean polar
Polar = 0.05

# %%
#Volume of coastal ocean (km^3)
Volume_C = V_ocean*Coastal
print(Volume_C)
# Out:
# 9060000.0

# %%
#Volume of open ocean (km^3)
Volume_O = V_ocean*Open
print(Volume_O)
# Out:
# 567760000.0

# %%
#Volume of deep ocean (km^3)
Volume_D = V_ocean*Deep
print(Volume_D)
# Out:
# 283880000.0

# %%
#Volume of polar ocean (km^3)
Volume_P = V_ocean*Polar
print(Volume_P)
# Out:
# 45300000.0

# %%
#Number of fish in the ocean
6000000000*Volume_C+75*Volume_P+50*Volume_D+200*Volume_O
# Out:
# 5.43601311435e+16

# %%
#scientific notation = 5.4 × 10^16
#actual number = 3.5 x 10^12

# %%
#Revised coastal density
NewCoastal = 50000
print(NewCoastal)
# Out:
# 50000

# %%
#New number of fish in the ocean
NewCoastal*Volume_C+75*Volume_P+50*Volume_D+200*Volume_O
# Out:
# 584143500000.0

# %%
#Scientific Notation
#6*10^11
